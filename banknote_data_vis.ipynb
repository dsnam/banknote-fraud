# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df = pd.read_csv('banknote.csv')
print df.columns
df_0 = df.iloc[list(np.where(df['class']==0)[0])]
df_1 = df.iloc[list(np.where(df['class']==1)[0])]
# Out:
# Index([u'var', u'skew', u'curt', u'ent', u'class'], dtype='object')

# %%
plt.scatter(df['var'],df['skew'],c=df['class'])
plt.show()

# %%
plt.scatter(df['var'],df['curt'],c=df['class'])
plt.show()

# %%
plt.scatter(df['var'],df['ent'],c=df['class'])
plt.show()

# %%
plt.scatter(df['skew'],df['curt'],c=df['class'])
plt.show()

# %%
plt.scatter(df['skew'],df['ent'],c=df['class'])
plt.show()

# %%
plt.scatter(df['curt'],df['ent'],c=df['class'])
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
xs = df['var']
ys = df['skew']
zs = df['ent']
ax.scatter(xs, ys, zs, c=df['class'], marker=m)

ax.set_xlabel('var')
ax.set_ylabel('skew')
ax.set_zlabel('ent')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
xs = df['skew']
ys = df['curt']
zs = df['var']
ax.scatter(xs, ys, zs, c=df['class'], marker=m)

ax.set_xlabel('skew')
ax.set_ylabel('curt')
ax.set_zlabel('var')

plt.show()
